# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
from my_import import *

# Set the path to the file you'd like to load
path = kagglehub.dataset_download("msafi04/movies-genre-dataset-cmu-movie-summary")
print("Path to dataset files:", path)
full_df=pd.read_csv(r"C:\Users\User\.cache\kagglehub\datasets\msafi04\movies-genre-dataset-cmu-movie-summary\versions\1\MovieSummaries\movie.metadata.tsv",sep='\t')
display(full_df)
# Export DataFrame to a CSV file
full_df.to_csv('your_file.csv', index=False)
# Out:
# Path to dataset files: C:\Users\User\.cache\kagglehub\datasets\msafi04\movies-genre-dataset-cmu-movie-summary\versions\1
#          975900   /m/03vyhn  \
# 0       3196793   /m/08yl5d
# 1      28463795  /m/0crgdbh
# 2       9363483  /m/0285_cd
# 3        261236   /m/01mrr1
# 4      13696889  /m/03cfc81
# ...         ...         ...
# 81735  35228177  /m/0j7hxnt
# 81736  34980460  /m/0g4pl34
# 81737   9971909  /m/02pygw1
# 81738    913762   /m/03pcrp
# 81739  12476867  /m/02w7zz8
#
#                                           Ghosts of Mars  2001-08-24  \
# 0      Getting Away with Murder: The JonBenét Ramsey ...  2000-02-16
# 1                                            Brun bitter        1988
# 2                                       White Of The Eye        1987
# 3                                      A Woman in Flames        1983
# 4                                          The Gangsters  1913-05-29
# ...                                                  ...         ...
# ...
